# %%
import glob
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
if __name__=="__main__":
	import sys
	sys.path.append('/Users/baljyot/Documents/CODE/GitHub_t2/Baljyot_EXP_RPOC/Scripts')

# %%
#import the data in /Users/baljyot/Documents/test_fixed/Analysis_new/testing_1_seg.tif_spots.csv

path = r'/Users/baljyot/Documents/test_fixed/Analysis_new/testing_1_seg.tif_spots.csv'
df = pd.read_csv(path)
df = df.drop([0,1,2])
df.head()
# Out:
#       LABEL      ID TRACK_ID             QUALITY          POSITION_X  \
# 3  ID156803  156803        0  57.220855712890625   21.23875308837087
# 4  ID156928  156928        0   74.69722747802734  21.147783343373675
# 5  ID156960  156960        0    11.1932373046875  21.189693990024324
# 6  ID156705  156705        0   67.37533569335938  21.158396914528694
# 7  ID156742  156742        0  51.263763427734375   21.19227081173508
#
#           POSITION_Y POSITION_Z POSITION_T FRAME RADIUS VISIBILITY  \
# 3  7.147551691943054        0.0        9.0     9    0.2          1
# 4  7.261030877470809        0.0       16.0    16    0.2          1
# 5  7.274161467467155        0.0       20.0    20    0.2          1
# 6  7.274839142725538        0.0        3.0     3    0.2          1
# 7  7.169982422087872        0.0        4.0     4    0.2          1
#
#   MANUAL_SPOT_COLOR  MEAN_INTENSITY_CH1 MEDIAN_INTENSITY_CH1  \
# 3               NaN  446.13513513513516                456.0
# ...

# %%
#lets see the POSITION_T column
df['POSITION_T'].head()
#find the values of TRACK_ID column which are '0'
df.loc[df['TRACK_ID'] == '0']
# Out:
#        LABEL      ID TRACK_ID             QUALITY          POSITION_X  \
# 3   ID156803  156803        0  57.220855712890625   21.23875308837087
# 4   ID156928  156928        0   74.69722747802734  21.147783343373675
# 5   ID156960  156960        0    11.1932373046875  21.189693990024324
# 6   ID156705  156705        0   67.37533569335938  21.158396914528694
# 7   ID156742  156742        0  51.263763427734375   21.19227081173508
# 8   ID156868  156868        0   49.00149917602539  21.264652839224762
# 9   ID156906  156906        0  17.643917083740234  21.187723106115474
# 10  ID156841  156841        0   63.26838302612305  21.179705091857034
# 11  ID156815  156815        0  63.622581481933594   21.18690765504242
# 12  ID156880  156880        0   90.19979858398438   21.12521901325536
# 13  ID156785  156785        0  105.15739440917969  21.170897137562584
# 14  ID156694  156694        0   83.30864715576172  21.300640495087993
# ...

# %%
#plot the POSITION_T column as a histogram
time = np.array(df['POSITION_T'], dtype = float)
plt.hist(time, bins = 50, density = False, alpha = 0.5, color = 'g')
plt.xlabel('Time')
plt.ylabel('PDF')
plt.title('Histogram of Time')
#plt.yscale('log')
# Out:
# Text(0.5, 1.0, 'Histogram of Time')
